# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Tao file test.txt de danh gia

# %%
# %cd /content/
# Out:
# /content

# %%
import zipfile 
import glob  
from skimage.io import imread  
from skimage.transform import resize  

img_list_test = sorted(glob.glob('/content/drive/MyDrive/CS114.FinalProject/Test/*.jpg'))

# %%
img_list_test

# %%
def write(my_list):
  with open('/content/drive/MyDrive/CS114.FinalProject/darknet_lan2/test.txt', 'w') as f:
    for item in my_list:
        f.write("%s\n" % item)

# %%
write(img_list_test)

# %% [markdown]
# Sửa lại trong file yolo.data trong darknet_lan2 valid=val.txt thành valid=test.txt

# %% [markdown]
# #Tinh mAp theo IoU

# %% [markdown]
# ##Yolov4 lan1(train 400 ảnh)

# %%
# %cd /content/drive/MyDrive/CS114.FinalProject/darknet_lan1
# !rm darknet
# !make
# Out:
# /content/drive/MyDrive/CS114.FinalProject/darknet_lan1
# chmod +x *.sh
# ...

# %%
# %cd /content/drive/MyDrive/CS114.FinalProject/darknet_lan1
# !./darknet detector map yolo.data cfg/yolov4-custom.cfg backup/yolov4-custom_best.weights -iou_thresh 0.5
# Out:
# /content/drive/MyDrive/CS114.FinalProject/darknet_lan1
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
# ...

# %%
# Tính mAP với Iou 0.75%
# %cd /content/drive/MyDrive/CS114.FinalProject/darknet_lan1
# !./darknet detector map yolo.data cfg/yolov4-custom.cfg backup/yolov4-custom_best.weights -iou_thresh 0.75
# Out:
# /content/drive/MyDrive/CS114.FinalProject/darknet_lan1
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
# ...

# %% [markdown]
# ##Yolov4 lan2 (train 800 ảnh)

# %%
# %cd /content/drive/MyDrive/CS114.FinalProject/darknet_lan2
# !rm darknet
# !make
# Out:
# /content/drive/MyDrive/CS114.FinalProject/darknet_lan2
# chmod +x *.sh
# ...

# %%
# %cd /content/drive/MyDrive/CS114.FinalProject/darknet_lan2
# !./darknet detector map yolo.data cfg/yolov4-custom.cfg backup/yolov4-custom_best.weights -iou_thresh 0.5
# Out:
# /content/drive/MyDrive/CS114.FinalProject/darknet_lan2
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
# ...

# %%
# Tính mAP với Iou 0.75%
# %cd /content/drive/MyDrive/CS114.FinalProject/darknet_lan2
# !./darknet detector map yolo.data cfg/yolov4-custom.cfg backup/yolov4-custom_best.weights -iou_thresh 0.75
# Out:
# /content/drive/MyDrive/CS114.FinalProject/darknet_lan2
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
# ...
